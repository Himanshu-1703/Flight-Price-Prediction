# %% [markdown]
# # Import the packages

# %%
import pandas as pd
import numpy as np
from sklearn import set_config,get_config
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler
from feature_engine.datetime import DatetimeFeatures

from sklearn.preprocessing import OneHotEncoder
from feature_engine.encoding import RareLabelEncoder
from sklearn.pipeline import FunctionTransformer

from feature_engine.discretisation import ArbitraryDiscretiser

import category_encoders as ce

from sklearn.preprocessing import TargetEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from feature_engine.outliers import Winsorizer

import seaborn as sns

from sklearn.base import BaseEstimator, TransformerMixin, OneToOneFeatureMixin
from sklearn.metrics.pairwise import rbf_kernel

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# get the config

get_config()
# Out:
# {'assume_finite': False,
#  'working_memory': 1024,
#  'print_changed_only': True,
#  'display': 'diagram',
#  'pairwise_dist_chunk_size': 256,
#  'enable_cython_pairwise_dist': True,
#  'array_api_dispatch': False,
#  'transform_output': 'default',
#  'enable_metadata_routing': False,
#  'skip_parameter_validation': False}

# %%
set_config(transform_output='pandas')

# %%
get_config()['transform_output']
# Out:
# 'pandas'

# %% [markdown]
# # Load and split the data

# %%
# load the data

data_path = "../data/cleaned_data.csv"

df = pd.read_csv(data_path)

df.head()
# Out:
#        airline    source destination departure_time arrival_time  duration  \
# 0       Indigo  Banglore       Delhi       22:20:00     01:10:00       170
# 1    Air_India   Kolkata    Banglore       05:50:00     13:15:00       445
# 2  Jet_Airways     Delhi      Cochin       09:25:00     04:25:00      1140
# 3       Indigo   Kolkata    Banglore       18:05:00     23:30:00       325
# 4       Indigo  Banglore       Delhi       16:50:00     21:35:00       285
#
#    total_stops  price  day_of_journey  month_of_journey
# 0            0   3897              24                 3
# 1            2   7662               1                 5
# 2            2  13882               9                 6
# 3            1   6218              12                 5
# 4            1  13302               1                 3

# %%
# check for missing values in the data

df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# **There are no missing values in the data**

# %%
# check for duplicate rows in data

df.duplicated().sum()
# Out:
# 2

# %%
# check rows which have duplicate values

(
    df
    .loc[
    df.duplicated(keep=False),:
    ]
)
# Out:
#        airline    source destination departure_time arrival_time  duration  \
# 1020  Air_Asia  Banglore       Delhi       23:25:00     02:10:00       165
# 5309   Vistara  Banglore       Delhi       21:10:00     00:05:00       175
# 6720   Vistara  Banglore       Delhi       21:10:00     00:05:00       175
# 8595  Air_Asia  Banglore       Delhi       23:25:00     02:10:00       165
#
#       total_stops  price  day_of_journey  month_of_journey
# 1020            0   4482              24                 3
# 5309            0   7608               3                 3
# 6720            0   7608               3                 3
# 8595            0   4482              24                 3

# %%
# drop the rows which have duplicate values

def drop_duplicate_rows(df:pd.DataFrame):
    return (
        df.drop_duplicates()
    )

df = drop_duplicate_rows(df)

# check for duplicates

df.duplicated().sum()
# Out:
# 0

# %%
# data types of df

df.dtypes
# Out:
# airline             object
# source              object
# destination         object
# departure_time      object
# arrival_time        object
# duration             int64
# total_stops          int64
# price                int64
# day_of_journey       int64
# month_of_journey     int64
# dtype: object

# %%
# split the data into train and test splits

train_data, test_data = train_test_split(df,test_size=0.2,random_state=42)

print('The shape of the train data is ',train_data.shape)
print('The shape of the test data is ',test_data.shape)
# Out:
# The shape of the train data is  (8368, 10)
# The shape of the test data is  (2092, 10)

# %% [markdown]
# # Column wise transformations

# %% [markdown]
# ## Airline

# %%
(
    train_data['airline']
    .value_counts(normalize=True)
)
# Out:
# airline
# Jet_Airways          0.354924
# Indigo               0.194551
# Air_India            0.163121
# Multiple_Carriers    0.114006
# Spicejet             0.075645
# Vistara              0.048040
# Air_Asia             0.030832
# Goair                0.018881
# Name: proportion, dtype: float64

# %%
airline_pipe = Pipeline(steps=[
    ('rare_cat',RareLabelEncoder(tol=0.1,n_categories=3,replace_with='Others')),
    ('encode',OneHotEncoder(sparse_output=False,handle_unknown='ignore'))
])

airline_pipe.fit_transform(train_data.loc[:,['airline']])
# Out:
#       airline_Air_India  airline_Indigo  airline_Jet_Airways  \
# 3457                1.0             0.0                  0.0
# 611                 1.0             0.0                  0.0
# 6553                1.0             0.0                  0.0
# 4521                1.0             0.0                  0.0
# 511                 0.0             0.0                  0.0
# ...                 ...             ...                  ...
# 5734                0.0             1.0                  0.0
# 5191                0.0             0.0                  1.0
# 5390                0.0             1.0                  0.0
# 860                 0.0             1.0                  0.0
# 7271                0.0             0.0                  1.0
#
#       airline_Multiple_Carriers  airline_Others
# 3457                        0.0             0.0
# 611                         0.0             0.0
# 6553                        0.0             0.0
# 4521                        0.0             0.0
# 511                         0.0             1.0
# ...                         ...             ...
# 5734                        0.0             0.0
# 5191                        0.0             0.0
# 5390                        0.0             0.0
# 860                         0.0             0.0
# 7271                        0.0             0.0
#
# [8368 rows x 5 columns]

# %%
airline_pipe.named_steps['rare_cat'].encoder_dict_
# Out:
# {'airline': ['Jet_Airways', 'Indigo', 'Air_India', 'Multiple_Carriers']}

# %%
airline_pipe
# Out:
# Pipeline(steps=[('rare_cat',
#                  RareLabelEncoder(n_categories=3, replace_with='Others',
#                                   tol=0.1)),
#                 ('encode',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ## Departure and Arrival times

# %%
time_subset = train_data.loc[:,['arrival_time','departure_time']]

# %%
time_subset
# Out:
#      arrival_time departure_time
# 3457     19:15:00       12:20:00
# 611      19:15:00       23:00:00
# 6553     17:10:00       14:10:00
# 4521     07:40:00       06:50:00
# 511      10:15:00       08:50:00
# ...           ...            ...
# 5734     11:20:00       08:30:00
# 5191     21:20:00       07:00:00
# 5390     15:35:00       10:35:00
# 860      08:50:00       05:35:00
# 7271     04:40:00       08:25:00
#
# [8368 rows x 2 columns]

# %%
times_pipe1 = Pipeline(steps=[
    ('dt',DatetimeFeatures(features_to_extract=['hour','minute'],format='mixed')),
    ('scale',MinMaxScaler())
])


times_pipe1.fit_transform(time_subset)
# Out:
#       arrival_time_hour  arrival_time_minute  departure_time_hour  \
# 3457           0.826087             0.272727             0.521739
# 611            0.826087             0.272727             1.000000
# 6553           0.739130             0.181818             0.608696
# 4521           0.304348             0.727273             0.260870
# 511            0.434783             0.272727             0.347826
# ...                 ...                  ...                  ...
# 5734           0.478261             0.363636             0.347826
# 5191           0.913043             0.363636             0.304348
# 5390           0.652174             0.636364             0.434783
# 860            0.347826             0.909091             0.217391
# 7271           0.173913             0.727273             0.347826
#
#       departure_time_minute
# 3457               0.363636
# 611                0.000000
# 6553               0.181818
# 4521               0.909091
# 511                0.909091
# ...                     ...
# 5734               0.545455
# 5191               0.000000
# 5390               0.636364
# 860                0.636364
# 7271               0.454545
#
# [8368 rows x 4 columns]

# %%
times_pipe1
# Out:
# Pipeline(steps=[('dt',
#                  DatetimeFeatures(features_to_extract=['hour', 'minute'],
#                                   format='mixed')),
#                 ('scale', MinMaxScaler())])

# %%
time_subset
# Out:
#      arrival_time departure_time
# 3457     19:15:00       12:20:00
# 611      19:15:00       23:00:00
# 6553     17:10:00       14:10:00
# 4521     07:40:00       06:50:00
# 511      10:15:00       08:50:00
# ...           ...            ...
# 5734     11:20:00       08:30:00
# 5191     21:20:00       07:00:00
# 5390     15:35:00       10:35:00
# 860      08:50:00       05:35:00
# 7271     04:40:00       08:25:00
#
# [8368 rows x 2 columns]

# %%
def binning(dataframe,morning=6,noon=12,evening=17,night=20):
    columns = dataframe.columns.to_list()
    X_temp = (
        dataframe
        .assign(**{
            col : pd.to_datetime(dataframe.loc[:,col],format='mixed').dt.hour
            for col in columns
        })
    )
    return (
        X_temp
        .assign(**{
            f'{col}_part_of_day': np.select(condlist=[
                X_temp.loc[:,col].between(morning,noon,inclusive='left'),
                X_temp.loc[:,col].between(noon,evening,inclusive='left'),
                X_temp.loc[:,col].between(evening,night,inclusive='left')
            ],
                          choicelist=[
                              "morning",
                              'noon',
                              'evening'
                          ],
                          default='night')
            for col in columns
        }
        )
        .drop(columns=columns)
    )

FunctionTransformer(binning).fit_transform(time_subset)
# Out:
#      arrival_time_part_of_day departure_time_part_of_day
# 3457                  evening                       noon
# 611                   evening                      night
# 6553                  evening                       noon
# 4521                  morning                    morning
# 511                   morning                    morning
# ...                       ...                        ...
# 5734                  morning                    morning
# 5191                    night                    morning
# 5390                     noon                    morning
# 860                   morning                      night
# 7271                    night                    morning
#
# [8368 rows x 2 columns]

# %%
times_pipe2 = Pipeline(steps=[
    ('binning',FunctionTransformer(func=binning)),
    ('count_encoding',ce.CountEncoder()),
    ('scaling',MinMaxScaler())
])

times_pipe2.fit_transform(time_subset)
# Out:
#       arrival_time_part_of_day  departure_time_part_of_day
# 3457                  0.130982                    0.062561
# 611                   0.130982                    0.405670
# 6553                  0.130982                    0.062561
# 4521                  0.115869                    1.000000
# 511                   0.115869                    1.000000
# ...                        ...                         ...
# 5734                  0.115869                    1.000000
# 5191                  1.000000                    1.000000
# 5390                  0.000000                    1.000000
# 860                   0.115869                    0.405670
# 7271                  1.000000                    1.000000
#
# [8368 rows x 2 columns]

# %%
times_pipe2
# Out:
# Pipeline(steps=[('binning',
#                  FunctionTransformer(func=<function binning at 0x000001EDF6FF4F40>)),
#                 ('count_encoding',
#                  CountEncoder(cols=['arrival_time_part_of_day',
#                                     'departure_time_part_of_day'],
#                               combine_min_nan_groups=True)),
#                 ('scaling', MinMaxScaler())])

# %%
time_union = FeatureUnion(transformer_list=[
    ('pipe_1',times_pipe1),
    ('pipe_2',times_pipe2)
],n_jobs=-1)

time_union.fit_transform(time_subset)
# Out:
#       arrival_time_hour  arrival_time_minute  departure_time_hour  \
# 3457           0.826087             0.272727             0.521739
# 611            0.826087             0.272727             1.000000
# 6553           0.739130             0.181818             0.608696
# 4521           0.304348             0.727273             0.260870
# 511            0.434783             0.272727             0.347826
# ...                 ...                  ...                  ...
# 5734           0.478261             0.363636             0.347826
# 5191           0.913043             0.363636             0.304348
# 5390           0.652174             0.636364             0.434783
# 860            0.347826             0.909091             0.217391
# 7271           0.173913             0.727273             0.347826
#
#       departure_time_minute  arrival_time_part_of_day  \
# 3457               0.363636                  0.130982
# 611                0.000000                  0.130982
# 6553               0.181818                  0.130982
# 4521               0.909091                  0.115869
# 511                0.909091                  0.115869
# ...                     ...                       ...
# 5734               0.545455                  0.115869
# 5191               0.000000                  1.000000
# 5390               0.636364                  0.000000
# 860                0.636364                  0.115869
# 7271               0.454545                  1.000000
#
#       departure_time_part_of_day
# 3457                    0.062561
# 611                     0.405670
# 6553                    0.062561
# 4521                    1.000000
# 511                     1.000000
# ...                          ...
# 5734                    1.000000
# 5191                    1.000000
# 5390                    1.000000
# 860                     0.405670
# 7271                    1.000000
#
# [8368 rows x 6 columns]

# %%
time_union
# Out:
# FeatureUnion(n_jobs=-1,
#              transformer_list=[('pipe_1',
#                                 Pipeline(steps=[('dt',
#                                                  DatetimeFeatures(features_to_extract=['hour',
#                                                                                        'minute'],
#                                                                   format='mixed')),
#                                                 ('scale', MinMaxScaler())])),
#                                ('pipe_2',
#                                 Pipeline(steps=[('binning',
#                                                  FunctionTransformer(func=<function binning at 0x000001EDFCF53D80>)),
#                                                 ('count_encoding',
#                                                  CountEncoder(cols=['arrival_time_part_of_day',
#                                                                     'departure_time_part_of_day'],
#                                                               combine_min_nan_groups=True)),
#                                                 ('scaling', MinMaxScaler())]))])

# %% [markdown]
# ## Source and Destination

# %%
location_subset = train_data.loc[:,['source','destination']]

location_subset
# Out:
#         source destination
# 3457     Delhi      Cochin
# 611      Delhi      Cochin
# 6553     Delhi      Cochin
# 4521     Delhi      Cochin
# 511     Mumbai   Hyderabad
# ...        ...         ...
# 5734  Banglore       Delhi
# 5191  Banglore       Delhi
# 5390     Delhi      Cochin
# 860      Delhi      Cochin
# 7271   Kolkata    Banglore
#
# [8368 rows x 2 columns]

# %%
(
    location_subset
    .loc[:,['source']]
    .value_counts(normalize=True)
)
# Out:
# source
# Delhi       0.413360
# Kolkata     0.275813
# Banglore    0.207576
# Mumbai      0.066444
# Chennai     0.036807
# Name: proportion, dtype: float64

# %%
(
    location_subset
    .loc[:,['destination']]
    .value_counts(normalize=True)
)
# Out:
# destination
# Cochin         0.413360
# Banglore       0.275813
# Delhi          0.207576
# Hyderabad      0.066444
# Kolkata        0.036807
# Name: proportion, dtype: float64

# %%
loc_pipe1 = Pipeline(steps=[
    ('rare_encode',RareLabelEncoder(tol=0.2,n_categories=3,replace_with='Other')),
    ('mean_encode',TargetEncoder(target_type='continuous',smooth=0.1,random_state=30)),
    ('power_transform',PowerTransformer())
])

loc_pipe1
# Out:
# Pipeline(steps=[('rare_encode',
#                  RareLabelEncoder(n_categories=3, replace_with='Other',
#                                   tol=0.2)),
#                 ('mean_encode',
#                  TargetEncoder(random_state=30, smooth=0.1,
#                                target_type='continuous')),
#                 ('power_transform', PowerTransformer())])

# %%
loc_pipe1.fit_transform(location_subset,train_data.loc[:,'price'])
# Out:
#         source  destination
# 3457  1.055535     1.055535
# 611   0.984361     0.984361
# 6553  1.055535     1.055535
# 4521  1.051186     1.051186
# 511  -1.894648    -1.894648
# ...        ...          ...
# 5734 -0.945825    -0.945825
# 5191 -0.889059    -0.889059
# 5390  1.055535     1.055535
# 860   1.086759     1.086759
# 7271 -0.218804    -0.218804
#
# [8368 rows x 2 columns]

# %%
def is_north_city(df):
    columns = df.columns.to_list()
    north_cities = ['Delhi','Kolkata']

    return (
        df
        .assign(**{
            f'{col}_is_north' : df.loc[:,col].isin(north_cities).astype(int)
            for col in columns
        })
        .drop(columns=columns)
    )
    
is_north_city(location_subset)
# Out:
#       source_is_north  destination_is_north
# 3457                1                     0
# 611                 1                     0
# 6553                1                     0
# 4521                1                     0
# 511                 0                     0
# ...               ...                   ...
# 5734                0                     1
# 5191                0                     1
# 5390                1                     0
# 860                 1                     0
# 7271                1                     0
#
# [8368 rows x 2 columns]

# %%
location_union = FeatureUnion(transformer_list=[
    ('pipe_1',loc_pipe1),
    ('pipe_2',FunctionTransformer(is_north_city))
],n_jobs=-1)

# %%
location_union
# Out:
# FeatureUnion(n_jobs=-1,
#              transformer_list=[('pipe_1',
#                                 Pipeline(steps=[('rare_encode',
#                                                  RareLabelEncoder(n_categories=3,
#                                                                   replace_with='Other',
#                                                                   tol=0.2)),
#                                                 ('mean_encode',
#                                                  TargetEncoder(random_state=30,
#                                                                smooth=0.1,
#                                                                target_type='continuous')),
#                                                 ('power_transform',
#                                                  PowerTransformer())])),
#                                ('pipe_2',
#                                 FunctionTransformer(func=<function is_north_city at 0x000001EDFD0ECE00>))])

# %%
location_union.fit_transform(location_subset,train_data.loc[:,'price'])
# Out:
#         source  destination  source_is_north  destination_is_north
# 3457  1.055535     1.055535                1                     0
# 611   0.984361     0.984361                1                     0
# 6553  1.055535     1.055535                1                     0
# 4521  1.051186     1.051186                1                     0
# 511  -1.894648    -1.894648                0                     0
# ...        ...          ...              ...                   ...
# 5734 -0.945825    -0.945825                0                     1
# 5191 -0.889059    -0.889059                0                     1
# 5390  1.055535     1.055535                1                     0
# 860   1.086759     1.086759                1                     0
# 7271 -0.218804    -0.218804                1                     0
#
# [8368 rows x 4 columns]

# %% [markdown]
# ## Duration

# %%
(
    train_data
    .loc[:,'duration']
)
# Out:
# 3457    1855
# 611     1215
# 6553     180
# 4521    1490
# 511       85
#         ...
# 5734     170
# 5191     860
# 5390     300
# 860      195
# 7271    1215
# Name: duration, Length: 8368, dtype: int64

# %%
(
    train_data
    .loc[:,['duration']]
    .quantile([0.25,0.5,0.75])
    .values
    .shape
)
# Out:
# (3, 1)

# %%
class RbfSimilarity(TransformerMixin,BaseEstimator,OneToOneFeatureMixin):

    def __init__(self,variables,percentiles,gamma=0.1):
        self.variables = variables
        self.percentiles = percentiles
        self.gamma = gamma
        
    def fit(self,X,y=None):
        self.quantile_values_ = {
            col : (
                X.loc[:,[col]]
                .quantile(self.percentiles)
                .values
            )
            for col in self.variables
        }
        
        return self

    def transform(self,X):
        objects = []
        for col in self.variables:
            columns = [f'{col}_rbf_{int(percentile*100)}' for percentile in self.percentiles]
            obj = pd.DataFrame(
                data=rbf_kernel(X.loc[:,[col]],Y=self.quantile_values_[col],gamma=self.gamma),
                columns=columns
            )
            objects.append(obj)
        return pd.concat(objects,axis=1)

# %%
rbf = RbfSimilarity(variables=['duration'],percentiles=[0.25,0.5,0.75])
rbf
# Out:
# RbfSimilarity(percentiles=[0.25, 0.5, 0.75], variables=['duration'])

# %%
rbf.fit(train_data.loc[:,['duration']])
# Out:
# RbfSimilarity(percentiles=[0.25, 0.5, 0.75], variables=['duration'])

# %%
rbf.quantile_values_['duration']
# Out:
# array([[170.],
#        [510.],
#        [925.]])

# %%
rbf.transform(train_data.loc[:,['duration']])
# Out:
#       duration_rbf_25  duration_rbf_50  duration_rbf_75
# 0        0.000000e+00              0.0     0.000000e+00
# 1        0.000000e+00              0.0     0.000000e+00
# 2        4.539993e-05              0.0     0.000000e+00
# 3        0.000000e+00              0.0     0.000000e+00
# 4       1.668157e-314              0.0     0.000000e+00
# ...               ...              ...              ...
# 8363     1.000000e+00              0.0     0.000000e+00
# 8364     0.000000e+00              0.0    3.240271e-184
# 8365     0.000000e+00              0.0     0.000000e+00
# 8366     7.187782e-28              0.0     0.000000e+00
# 8367     0.000000e+00              0.0     0.000000e+00
#
# [8368 rows x 3 columns]

# %%
# #duration_pipe = Pipeline(steps=[
#     #('rbf_similarity',RbfSimilarity(variables=['duration'],percentiles=[0.25,0.5,0.75])),
#     #('transform',PowerTransformer())
# ])

# #duration_pipe.fit_transform(train_data.loc[:,['duration']])

# %%
#duration_pipe

# %%
duration_union = FeatureUnion(transformer_list=[
    ('power_transform',PowerTransformer()),
    ('scaling',StandardScaler())
])

duration_union
# Out:
# FeatureUnion(transformer_list=[('power_transform', PowerTransformer()),
#                                ('scaling', StandardScaler())])

# %%
train_data.columns
# Out:
# Index(['airline', 'source', 'destination', 'departure_time', 'arrival_time',
#        'duration', 'total_stops', 'price', 'day_of_journey',
#        'month_of_journey'],
#       dtype='object')

# %% [markdown]
# ## Total Stops

# %%
def no_stops(X):
    columns_list = X.columns.to_list()

    return (
        X
        .assign(**{
            col : np.where(X[col]==0,1,0)
            for col in columns_list
        })
    )

no_stops(train_data.loc[:,['total_stops']]).value_counts()
# Out:
# total_stops
# 0              5612
# 1              2756
# Name: count, dtype: int64

# %%
(
    train_data
    .loc[:,['total_stops']]
    .value_counts()
)
# Out:
# total_stops
# 1              4506
# 0              2756
# 2              1074
# 3                32
# Name: count, dtype: int64

# %% [markdown]
# # Column Transformers

# %%
train_data.columns
# Out:
# Index(['airline', 'source', 'destination', 'departure_time', 'arrival_time',
#        'duration', 'total_stops', 'price', 'day_of_journey',
#        'month_of_journey'],
#       dtype='object')

# %%
preprocessor = ColumnTransformer(transformers=[
    ('airline',airline_pipe,['airline']),
    ('journey',MinMaxScaler(),['day_of_journey','month_of_journey']),
    ('time',time_union,['arrival_time','departure_time']),
    ('location',location_union,['source','destination']),
    ('duration',duration_union,['duration']),
    ('total_stops',FunctionTransformer(no_stops),['total_stops'])
],n_jobs=-1,verbose_feature_names_out=False)

preprocessor
# Out:
# ColumnTransformer(n_jobs=-1,
#                   transformers=[('airline',
#                                  Pipeline(steps=[('rare_cat',
#                                                   RareLabelEncoder(n_categories=3,
#                                                                    replace_with='Others',
#                                                                    tol=0.1)),
#                                                  ('encode',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['airline']),
#                                 ('journey', MinMaxScaler(),
#                                  ['day_of_journey', 'month_of_journey']),
#                                 ('time',
#                                  FeatureUnion(n_jobs=-1,
#                                               transformer_list=[('pipe...
#                                                                  FunctionTransformer(func=<function is_north_city at 0x000001EDFD0ED800>))]),
#                                  ['source', 'destination']),
#                                 ('duration',
#                                  FeatureUnion(transformer_list=[('power_transform',
#                                                                  PowerTransformer()),
#                                                                 ('scaling',
#                                                                  StandardScaler())]),
#                                  ['duration']),
#                                 ('total_stops',
#                                  FunctionTransformer(func=<function no_stops at 0x000001EDFF0C4400>),
#                                  ['total_stops'])],
#                   verbose_feature_names_out=False)

# %%
y_train = train_data.loc[:,'price']

# %%
preprocessor.fit_transform(train_data,y_train)
# Out:
#       airline_Air_India  airline_Indigo  airline_Jet_Airways  \
# 3457                1.0             0.0                  0.0
# 611                 1.0             0.0                  0.0
# 6553                1.0             0.0                  0.0
# 4521                1.0             0.0                  0.0
# 511                 0.0             0.0                  0.0
# ...                 ...             ...                  ...
# 5734                0.0             1.0                  0.0
# 5191                0.0             0.0                  1.0
# 5390                0.0             1.0                  0.0
# 860                 0.0             1.0                  0.0
# 7271                0.0             0.0                  1.0
#
#       airline_Multiple_Carriers  airline_Others  day_of_journey  \
# 3457                        0.0             0.0        1.000000
# 611                         0.0             0.0        0.769231
# 6553                        0.0             0.0        1.000000
# 4521                        0.0             0.0        0.538462
# 511                         0.0             1.0        0.307692
# ...                         ...             ...             ...
# 5734                        0.0             0.0        0.076923
# 5191                        0.0             0.0        0.769231
# 5390                        0.0             0.0        0.076923
# 860                         0.0             0.0        1.000000
# 7271                        0.0             0.0        0.307692
#
#       month_of_journey  arrival_time_hour  arrival_time_minute  \
# 3457          0.666667           0.826087             0.272727
# 611           0.000000           0.826087             0.272727
# 6553          0.333333           0.739130             0.181818
# 4521          1.000000           0.304348             0.727273
# 511           0.000000           0.434783             0.272727
# ...                ...                ...                  ...
# 5734          1.000000           0.478261             0.363636
# 5191          0.000000           0.913043             0.363636
# 5390          0.333333           0.652174             0.636364
# 860           0.333333           0.347826             0.909091
# 7271          1.000000           0.173913             0.727273
#
#       departure_time_hour  departure_time_minute  arrival_time_part_of_day  \
# 3457             0.521739               0.363636                  0.130982
# 611              1.000000               0.000000                  0.130982
# 6553             0.608696               0.181818                  0.130982
# 4521             0.260870               0.909091                  0.115869
# 511              0.347826               0.909091                  0.115869
# ...                   ...                    ...                       ...
# 5734             0.347826               0.545455                  0.115869
# 5191             0.304348               0.000000                  1.000000
# 5390             0.434783               0.636364                  0.000000
# 860              0.217391               0.636364                  0.115869
# 7271             0.347826               0.454545                  1.000000
#
#       departure_time_part_of_day    source  destination  source_is_north  \
# 3457                    0.062561  1.055535     1.055535                1
# 611                     0.405670  0.984361     0.984361                1
# 6553                    0.062561  1.055535     1.055535                1
# 4521                    1.000000  1.051186     1.051186                1
# 511                     1.000000 -1.894648    -1.894648                0
# ...                          ...       ...          ...              ...
# 5734                    1.000000 -0.945825    -0.945825                0
# 5191                    1.000000 -0.889059    -0.889059                0
# 5390                    1.000000  1.055535     1.055535                1
# 860                     0.405670  1.086759     1.086759                1
# 7271                    1.000000 -0.218804    -0.218804                1
#
#       destination_is_north  power_transform__duration  scaling__duration  \
# 3457                     0                   1.678467           2.424604
# 611                      0                   1.138053           1.151704
# 6553                     0                  -0.998730          -0.906813
# 4521                     0                   1.395373           1.698654
# 511                      0                  -1.715677          -1.095759
# ...                    ...                        ...                ...
# 5734                     1                  -1.055650          -0.926702
# 5191                     1                   0.715703           0.445643
# 5390                     0                  -0.472645          -0.668145
# 860                      0                  -0.918372          -0.876980
# 7271                     0                   1.138053           1.151704
#
#       total_stops
# 3457            0
# 611             0
# 6553            1
# 4521            0
# 511             1
# ...           ...
# 5734            1
# 5191            0
# 5390            0
# 860             1
# 7271            0
#
# [8368 rows x 20 columns]

# %%
preprocessor_pipe = Pipeline(steps=[
    ('remove_outliers',Winsorizer(capping_method='iqr',fold=1.5,tail='both',variables=['duration'])),
    ('preprocessor',preprocessor)
])

preprocessor_pipe
# Out:
# Pipeline(steps=[('remove_outliers',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['duration'])),
#                 ('preprocessor',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('airline',
#                                                   Pipeline(steps=[('rare_cat',
#                                                                    RareLabelEncoder(n_categories=3,
#                                                                                     replace_with='Others',
#                                                                                     tol=0.1)),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['ai...
#                                                                                   FunctionTransformer(func=<function is_north_city at 0x000001EDFD0ED800>))]),
#                                                   ['source', 'destination']),
#                                                  ('duration',
#                                                   FeatureUnion(transformer_list=[('power_transform',
#                                                                                   PowerTransformer()),
#                                                                                  ('scaling',
#                                                                                   StandardScaler())]),
#                                                   ['duration']),
#                                                  ('total_stops',
#                                                   FunctionTransformer(func=<function no_stops at 0x000001EDFF0C4400>),
#                                                   ['total_stops'])],
#                                    verbose_feature_names_out=False))])

# %%
preprocessor_pipe.fit_transform(train_data,y_train)
# Out:
#       airline_Air_India  airline_Indigo  airline_Jet_Airways  \
# 3457                1.0             0.0                  0.0
# 611                 1.0             0.0                  0.0
# 6553                1.0             0.0                  0.0
# 4521                1.0             0.0                  0.0
# 511                 0.0             0.0                  0.0
# ...                 ...             ...                  ...
# 5734                0.0             1.0                  0.0
# 5191                0.0             0.0                  1.0
# 5390                0.0             1.0                  0.0
# 860                 0.0             1.0                  0.0
# 7271                0.0             0.0                  1.0
#
#       airline_Multiple_Carriers  airline_Others  day_of_journey  \
# 3457                        0.0             0.0        1.000000
# 611                         0.0             0.0        0.769231
# 6553                        0.0             0.0        1.000000
# 4521                        0.0             0.0        0.538462
# 511                         0.0             1.0        0.307692
# ...                         ...             ...             ...
# 5734                        0.0             0.0        0.076923
# 5191                        0.0             0.0        0.769231
# 5390                        0.0             0.0        0.076923
# 860                         0.0             0.0        1.000000
# 7271                        0.0             0.0        0.307692
#
#       month_of_journey  arrival_time_hour  arrival_time_minute  \
# 3457          0.666667           0.826087             0.272727
# 611           0.000000           0.826087             0.272727
# 6553          0.333333           0.739130             0.181818
# 4521          1.000000           0.304348             0.727273
# 511           0.000000           0.434783             0.272727
# ...                ...                ...                  ...
# 5734          1.000000           0.478261             0.363636
# 5191          0.000000           0.913043             0.363636
# 5390          0.333333           0.652174             0.636364
# 860           0.333333           0.347826             0.909091
# 7271          1.000000           0.173913             0.727273
#
#       departure_time_hour  departure_time_minute  arrival_time_part_of_day  \
# 3457             0.521739               0.363636                  0.130982
# 611              1.000000               0.000000                  0.130982
# 6553             0.608696               0.181818                  0.130982
# 4521             0.260870               0.909091                  0.115869
# 511              0.347826               0.909091                  0.115869
# ...                   ...                    ...                       ...
# 5734             0.347826               0.545455                  0.115869
# 5191             0.304348               0.000000                  1.000000
# 5390             0.434783               0.636364                  0.000000
# 860              0.217391               0.636364                  0.115869
# 7271             0.347826               0.454545                  1.000000
#
#       departure_time_part_of_day    source  destination  source_is_north  \
# 3457                    0.062561  1.055535     1.055535                1
# 611                     0.405670  0.984361     0.984361                1
# 6553                    0.062561  1.055535     1.055535                1
# 4521                    1.000000  1.051186     1.051186                1
# 511                     1.000000 -1.894648    -1.894648                0
# ...                          ...       ...          ...              ...
# 5734                    1.000000 -0.945825    -0.945825                0
# 5191                    1.000000 -0.889059    -0.889059                0
# 5390                    1.000000  1.055535     1.055535                1
# 860                     0.405670  1.086759     1.086759                1
# 7271                    1.000000 -0.218804    -0.218804                1
#
#       destination_is_north  power_transform__duration  scaling__duration  \
# 3457                     0                   1.686381           2.450037
# 611                      0                   1.141704           1.165328
# 6553                     0                  -0.999708          -0.912288
# 4521                     0                   1.400909           1.717352
# 511                      0                  -1.713324          -1.102987
# ...                    ...                        ...                ...
# 5734                     1                  -1.056459          -0.932361
# 5191                     1                   0.716846           0.452716
# 5390                     0                  -0.474420          -0.671405
# 860                      0                  -0.919558          -0.882177
# 7271                     0                   1.141704           1.165328
#
#       total_stops
# 3457            0
# 611             0
# 6553            1
# 4521            0
# 511             1
# ...           ...
# 5734            1
# 5191            0
# 5390            0
# 860             1
# 7271            0
#
# [8368 rows x 20 columns]
